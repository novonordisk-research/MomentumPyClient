# %%
from MomentumPyClient import Momentum
import pandas as pd
import time

m = Momentum()
m.get_status()
# Out:
# {'State': 'Online', 'Attended': True, 'Simulated': True}

# %%
m.get_version()
# Out:
# {'Version': '7.1.4'}

# %%
m.stop()
m.get_status()
# Out:
# {'State': 'Stopping', 'Attended': True, 'Simulated': True}

# %%
m.simulate()
time.sleep(2)
m.get_status()
# Out:
# {'State': 'Online', 'Attended': True, 'Simulated': True}

# %%
m.get_instrument_names()
# Out:
# ['a4S',
#  'Bioshake_1',
#  'Bioshake_2',
#  'Carousel',
#  'DynaPro',
#  'Echo',
#  'Hotel',
#  'Liconic_1',
#  'Liconic_2',
#  'Liconic_3',
#  'Lidpark',
#  'Mantis',
#  'MicroSpin',
#  'PassiveNest_1',
#  'PassiveNest_2',
#  'RotationStation',
#  'SpinnakerBT_1',
#  'SpinnakerBT_2',
#  'SwapStation',
#  'Tecan_Fluent',
#  'Tecan_Spark',
#  'Waste',
#  'XPeel']

# %%
pd.DataFrame(m.get_devices())
# Out:
#                                       Id                 Name    Mode   State  \
# 0   4f51db55-ca7c-4727-81c1-f6f802364f7c                  a4S  Normal  Online
# 1   d1b589d4-9635-4dfc-b9b5-7f64d7e1a351  ApplicationLauncher  Normal  Online
# 2   6043bfa4-3328-4cbc-a600-05afc956b7cc               Beacon  Normal  Online
# 3   3a7fddd5-cdc7-4978-a6d4-03e9819a565e           Bioshake_1  Normal  Online
# 4   51806669-d2ac-410a-8cae-f55dec5e03b1           Bioshake_2  Normal  Online
# 5   1335f9d0-6337-42fc-bc3a-d45ad209c15c             Carousel  Normal  Online
# 6   d6659913-6630-4f50-8b9d-815da7740772     ContainerScanner  Normal  Online
# 7   51b3c4f6-95cb-479d-b625-01d06add1a2d            DataMiner  Normal  Online
# 8   eeba0e63-1fa1-4b4c-9db1-f22020d468a9              Docking  Normal  Online
# 9   5dd5ab0d-1990-4061-9e20-2eaef1805c39              DynaPro  Normal  Online
# 10  4037e7bd-b249-425a-92ce-ae24dfa14109                 Echo  Normal  Online
# 11  afb5b5c3-c91e-49e3-8430-1de6f824e0f6          FileManager  Normal  Online
# 12  a0387028-39c6-49f8-9f94-9e359b7aa6de                Hotel  Normal  Online
# 13  593a806e-38bf-4c37-9830-b8e5cd5f0e52            Liconic_1  Normal  Online
# 14  b0a8db49-ee8c-4383-a878-cdcc5df4e8cb            Liconic_2  Normal  Online
# 15  9110a8a1-6564-447c-b639-07da8cabefbb            Liconic_3  Normal  Online
# 16  b1e7f0fd-0cdb-4f83-af68-0b1730f95c05              Lidpark  Normal  Online
# 17  778eed5c-429f-40ac-9f5f-2d478dbb27c0               Mantis  Normal  Online
# 18  084a8047-733e-44bd-a110-ca04bfd6d77a            MicroSpin  Normal  Online
# 19  9c67eb09-1be9-4534-91b8-e83f57237e2e     MomentumOperator  Normal  Online
# 20  ed1d474e-245c-46a7-8054-ab48a6b9379c        PassiveNest_1  Normal  Online
# 21  1910398c-f5f7-4a4b-aa5e-2a8dcde99c79        PassiveNest_2  Normal  Online
# 22  5969fdbb-72d4-41de-a7ea-ab8a036be7d3      RotationStation  Normal  Online
# 23  2dc029f7-4437-40e6-8e82-8536ef567a54        SpinnakerBT_1  Normal  Online
# 24  dd83075e-9cb5-4347-8308-43b79ba1cacc        SpinnakerBT_2  Normal  Online
# 25  489733e8-11d1-4b91-b731-cfa5a4e45947          SwapStation  Normal  Online
# 26  f47443eb-024d-477b-8cd4-708c8b02c957         Tecan_Fluent  Normal  Online
# 27  579119fc-de14-4743-b968-01abc7d1634c          Tecan_Spark  Normal  Online
# 28  c5a69267-4d61-41c1-a357-0f954f2d5605                Waste  Normal  Online
# 29  5e30c241-4c66-41b0-9c5e-4722b015fa37          Wtio_Beacon  Normal  Online
# 30  938c77b6-f4a5-4313-a5bf-4a9c76863963         Wtio_Lidpark  Normal  Online
# 31  3701c66e-dfe3-49a0-a977-1bd3de521907          Wtio_Regrip  Normal  Online
# 32  815d9399-7927-4c54-9fdb-fb811fe32c8b                XPeel  Normal  Online
#
#    OnlineState  Active  Available DockState  Present  IsSimulated  \
# 0         Idle   False       True    Docked     True         True
# 1         Idle   False       True    Docked     True         True
# 2         Idle   False       True    Docked     True         True
# 3         Idle   False       True    Docked     True         True
# 4         Idle   False       True    Docked     True         True
# 5         Idle   False       True    Docked     True         True
# 6         Idle   False       True    Docked     True         True
# 7         Idle   False       True    Docked     True         True
# 8         Idle   False       True    Docked     True         True
# 9         Idle   False       True    Docked     True         True
# 10        Idle   False       True    Docked     True         True
# 11        Idle   False       True    Docked     True         True
# 12        Idle   False       True    Docked     True         True
# 13        Idle   False       True    Docked     True         True
# 14        Idle   False       True    Docked     True         True
# 15        Idle   False       True    Docked     True         True
# 16        Idle   False       True    Docked     True         True
# 17        Idle   False       True    Docked     True         True
# 18        Idle   False       True    Docked     True         True
# 19        Idle   False       True    Docked     True         True
# 20        Idle   False       True    Docked     True         True
# 21        Idle   False       True    Docked     True         True
# 22        Idle   False       True    Docked     True         True
# 23        Idle   False       True    Docked     True         True
# 24        Idle   False       True    Docked     True         True
# 25        Idle   False       True    Docked     True         True
# 26        Idle   False       True    Docked     True         True
# 27        Idle   False       True    Docked     True         True
# 28        Idle   False       True    Docked     True         True
# 29        Idle   False       True    Docked     True         True
# 30        Idle   False       True    Docked     True         True
# 31        Idle   False       True    Docked     True         True
# 32        Idle   False       True    Docked     True         True
#
#     IsInstrument  Priority FirmwareVersion  \
# 0           True         2            515A
# 1          False         2  Not available.
# 2          False         2  Not available.
# 3           True         2          1.8.00
# 4           True         2          1.8.00
# 5           True         2  Not available.
# 6          False         2             N/A
# 7          False         2  Not available.
# 8          False         0  Not available.
# 9           True         2  Not available.
# 10          True         2  Not available.
# 11         False         2  Not available.
# 12          True         2  Not available.
# 13          True         2  Not available.
# 14          True         2  Not available.
# 15          True         2  Not available.
# 16          True         2  Not available.
# 17          True         2  Not available.
# 18          True         2  Not available.
# 19         False         2  Not available.
# 20          True         2  Not available.
# 21          True         2  Not available.
# 22          True         2  Not available.
# 23          True         1  Not available.
# 24          True         1  Not available.
# 25          True         2  Not available.
# 26          True         2  Not available.
# 27          True         2  Not available.
# 28          True         2  Not available.
# 29         False         0  Not available.
# 30         False         0  Not available.
# 31         False         0  Not available.
# 32          True         2            2.11
#
#                              SoftwareVersion  \
# 0                 Communication Protocol 1.7
# 1                             Not available.
# 2                             Not available.
# 3                             Not available.
# 4                             Not available.
# 5                             Not available.
# 6                                    3.0.0.0
# 7                             Not available.
# 8                             Not available.
# 9                             Not available.
# 10                                     3.2.2
# 11                            Not available.
# 12                            Not available.
# 13                                       N/A
# 14                                       N/A
# 15                                       N/A
# 16                            Not available.
# 17                            Not available.
# 18                            Not available.
# 19                            Not available.
# 20                            Not available.
# 21                            Not available.
# 22                            Not available.
# 23  Thermo Scientific Mover Framework 2.4.28
# 24  Thermo Scientific Mover Framework 2.4.28
# 25                            Not available.
# 26                            Not available.
# 27                            Not available.
# 28                            Not available.
# 29                            Not available.
# 30                            Not available.
# 31                            Not available.
# 32                                       N/A
#
#                               ModelDescription    SerialNumber ConnectionMode  \
# 0                               Not available.  Not available.        Unknown
# 1                               Not available.  Not available.        Unknown
# 2                               Not available.  Not available.        Unknown
# 3                      Q.MTP-BIOSHAKE 5000 elm  Not available.        Unknown
# 4                      Q.MTP-BIOSHAKE 5000 elm  Not available.        Unknown
# 5                               Not available.  Not available.        Unknown
# 6             Thermo.Momentum.ContainerScanner             N/A        Unknown
# 7                               Not available.  Not available.        Unknown
# 8                               Not available.  Not available.        Unknown
# 9                               Not available.  Not available.        Unknown
# 10                                    Echo 650      E6XX-22158        Unknown
# 11                              Not available.  Not available.        Unknown
# 12                              Not available.  Not available.        Unknown
# 13                                      STX110  Not available.        Unknown
# 14                                      STX110  Not available.        Unknown
# 15                                      STX110  Not available.        Unknown
# 16                              Not available.  Not available.        Unknown
# 17                              Not available.  Not available.        Unknown
# 18                              Not available.  Not available.        Unknown
# 19                              Not available.  Not available.        Unknown
# 20                              Not available.  Not available.        Unknown
# 21                              Not available.  Not available.        Unknown
# 22                              Not available.  Not available.        Unknown
# 23  Thermo Scientific Spinnaker with BenchTrak  Not available.        Unknown
# 24  Thermo Scientific Spinnaker with BenchTrak  Not available.        Unknown
# 25                              Not available.  Not available.        Unknown
# 26                              Not available.  Not available.        Unknown
# 27                              Not available.  Not available.        Unknown
# 28                              Not available.  Not available.        Unknown
# 29                              Not available.  Not available.        Unknown
# 30                              Not available.  Not available.        Unknown
# 31                              Not available.  Not available.        Unknown
# 32                      Nexus Biosystems XPeel                        Unknown
#
#                                                 Type  IsWasteInstrument
# 0             4titude Automatic Roll Heat Sealer a4S              False
# 1             Thermo Scientific Application Launcher              False
# 2                           Thermo Scientific Beacon              False
# 3         QInstruments BioShake 5000 Series - Single              False
# 4         QInstruments BioShake 5000 Series - Single              False
# 5   Thermo Scientific Thermotor Carousel - 8 Columns              False
# 6                Thermo Scientific Container Scanner              False
# 7                       Thermo Scientific Data Miner              False
# 8           Thermo Scientific Docking Inputs Monitor              False
# 9                                      Wyatt DynaPro              False
# 10                Labcyte Echo6XX Acoustic Dispenser              False
# 11                    Thermo Scientific File Manager              False
# 12               Thermo Scientific General Incubator              False
# 13               Liconic StoreX STX Series Incubator              False
# 14               Liconic StoreX STX Series Incubator              False
# 15               Liconic StoreX STX Series Incubator              False
# 16       Thermo Scientific Lid Park Station Delidder              False
# 17                                Formulatrix Mantis              False
# 18                      HighRes MicroSpin Centrifuge              False
# 19             Thermo Scientific Momentum Operator 4              False
# 20               Thermo Scientific General Incubator              False
# 21               Thermo Scientific General Incubator              False
# 22                Thermo Scientific Rotation Station              False
# 23                           Thermo Scientific Mover              False
# 24                           Thermo Scientific Mover              False
# 25                    Thermo Scientific Swap Station              False
# 26                                      Tecan Fluent              False
# 27                             Tecan Spark(Magellan)              False
# 28                   Thermo Scientific General Waste               True
# 29          White Tree Technology WTIO-1 Input/Ouput              False
# 30          White Tree Technology WTIO-1 Input/Ouput              False
# 31          White Tree Technology WTIO-1 Input/Ouput              False
# 32                            Nexus Biosystems XPeel              False

# %%
pd.DataFrame(m.get_containers())
# Out:
#                                       Id  \
# 0   44168865-b358-4ab2-91c8-0ff0dbfb65da
# 1   9f081794-ca07-4e49-8488-d796da97ddaf
# 2   b52528eb-85c8-4971-aee7-5dbb545caf65
# 3   320fd079-4dfc-42d1-985a-3e441abde778
# 4   0f5eadf8-3ef0-4716-b546-22bfe4311ca9
# 5   c9bfeac8-9550-4dd3-88c5-57af717d684d
# 6   3238da6f-f02e-4d2b-9b13-31a26a6314ae
# 7   1895c5fd-5a87-41bb-b114-6df445f93b56
# 8   64ec87c4-b29c-46ec-a8c6-e0125d5af2df
# 9   de93f090-73bf-4288-b158-baec7c85019b
# 10  f8d7f5f9-f057-4f75-85c1-787adddbeb7b
# 11  0597df70-ac6c-4fc2-a016-c81384d8920d
# 12  f6b5ed05-5877-4676-99b4-2f63e61a2c2c
# 13  043f7b53-612b-4262-818a-714402fc66b2
# 14  9ed68ad3-12b3-4959-9da7-811b140b1d44
# 15  67951823-3b6a-4e9b-9854-51bbc8b4f6aa
# 16  19b017c2-2096-46db-8bd4-b9eab27cbb00
# 17  af4a93b4-b356-4ba8-8aba-7e5db24d9d98
# 18  1ce7dd67-8085-4728-b159-56c0ebb944fc
# 19  a94362e8-9204-4283-b56f-e0650720ca1b
# 20  1df7d41c-f08f-42f5-991c-4fe8cdd17427
# 21  e2e3fc70-22bf-4fd2-8901-7875abe06d8e
# 22  d8a3d847-2236-4924-9918-0587e60a25d6
# 23  41762ec9-5663-4913-8824-fbec0b4a132f
# 24  c96aeb3f-485e-4150-a587-05c5f834d1df
# 25  28cd3f4c-eed5-4c13-806c-5ef76587cf32
# 26  66f1c0dd-7183-4f9e-a6eb-01feb6d23a8d
# 27  ba471d87-ac33-4bd5-8315-2f8a1910ac3e
# 28  489322ea-8755-4fc6-a0bf-6b3e91dd775b
# 29  5f923e1f-1b78-4731-844a-c87a5d90bfaa
# 30  858fa1fe-7a1a-49b6-b3f4-f9cd0883340b
# 31  315d8c19-5b48-4412-9912-115caa12a850
# 32  3edd85cf-30c4-4750-a78f-74b2567e72cd
# 33  23ff39af-58cf-4e88-8ad6-d7565d766aaf
# 34  265d1e01-602e-4621-b4b4-06465371ca28
# 35  b6eb42df-d6ba-4b02-a253-6116a1cd179e
# 36  1d23726b-cbb7-44d8-85a8-eaf7e527309a
# 37  bf5317df-985c-4717-b413-428cbd262907
#
#                                                  Name  \
# 0   T_SaltTitration_Destination (Id: 2380, Barcode...
# 1   T_OrangeGTest (Id: 2381, Barcode: NC2023022100...
# 2   T_OrangeGTest (Id: 2383, Barcode: NC2023022100...
# 3   T_AC_SINS_Destination (Id: 1397, Barcode: NN00...
# 4   T_OrangeGTest (Id: 2387, Barcode: NC2023022100...
# 5   T_OrangeGTest (Id: 2382, Barcode: NC2023022100...
# 6   T_AC_SINS_Destination (Id: 1399, Barcode: NN00...
# 7   T_OrangeGTest (Id: 2388, Barcode: NC2023022100...
# 8   T_OrangeGTest (Id: 2384, Barcode: NC2023022100...
# 9   T_AC_SINS_Destination (Id: 1401, Barcode: NN00...
# 10  T_OrangeGTest (Id: 2389, Barcode: NC2023022100...
# 11  T_OrangeGTest (Id: 2385, Barcode: NC2023022100...
# 12  T_AC_SINS_Destination (Id: 1403, Barcode: NN00...
# 13  T_OrangeGTest (Id: 2390, Barcode: NC2023022100...
# 14  T_OrangeGTest (Id: 2386, Barcode: NC2023022100...
# 15  T_AC_SINS_Destination (Id: 1405, Barcode: NN00...
# 16  T_AC_SINS_Destination (Id: 1407, Barcode: NN00...
# 17    T_Displacement_Assay (Id: 2226, Barcode: test3)
# 18    T_Displacement_Assay (Id: 2227, Barcode: test4)
# 19    T_Displacement_Assay (Id: 2228, Barcode: test5)
# 20      T_OrangeGTest (Id: 2378, Barcode: JSQP241219)
# 21    T_Displacement_Assay (Id: 2375, Barcode: test6)
# 22      T_OrangeGTest (Id: 2377, Barcode: JSQP241218)
# 23      T_OrangeGTest (Id: 2376, Barcode: JSQP241217)
# 24                       T_CounterBalance1 (Id: 1410)
# 25         T_kD_source (Id: 2238, Barcode: barcode 1)
# 26          T_kD_Assay (Id: 2236, Barcode: barcode 2)
# 27      T_DLS_Stability (Id: 2321, Barcode: DLS_Stab)
# 28     T_greiner788876 (Id: 1908, Barcode: barcode 4)
# 29  T_AC_SINS_Destination (Id: 2367, Barcode: C502...
# 30  T_AC_SINS_Destination (Id: 2373, Barcode: C503...
# 31  T_AC_SINS_Destination (Id: 2369, Barcode: C502...
# 32  T_AC_SINS_Destination (Id: 2371, Barcode: C503...
# 33   T_AC_SINS_Source (Id: 1395, Barcode: NN0001T2Q2)
# 34   T_AC_SINS_Source (Id: 1396, Barcode: NN0001T2TR)
# 35   T_kD_Intermediate (Id: 2237, Barcode: barcode 3)
# 36  T_AC_SINS_Source (Id: 2229, Barcode: AC-SINS_R...
# 37                       T_CounterBalance2 (Id: 1409)
#
#                      Barcode       State AbortState FinishState  \
# 0                      salt1  Undetected       None          Ok
# 1       NC20230221000003.000     Present       None          Ok
# 2       NC20230221000003.000     Present       None          Ok
# 3                 NN0001SYUB    Complete       None          Ok
# 4       NC20230221000003.000     Present       None          Ok
# 5       NC20230221000003.000     Present       None          Ok
# 6                 NN0001SYUA     Present       None          Ok
# 7       NC20230221000003.000     Present       None          Ok
# 8       NC20230221000003.000     Present       None          Ok
# 9                 NN0001SYU9     Present       None          Ok
# 10      NC20230221000003.000     Present       None          Ok
# 11      NC20230221000003.000     Present       None          Ok
# 12                NN0001SYU8     Present       None          Ok
# 13      NC20230221000003.000     Present       None          Ok
# 14      NC20230221000003.000     Present       None          Ok
# 15                NN0001SYU7     Present       None          Ok
# 16                NN0001SYU6     Present       None          Ok
# 17                     test3  Undetected       None          Ok
# 18                     test4  Undetected       None          Ok
# 19                     test5  Undetected       None          Ok
# 20                JSQP241219  Undetected       None          Ok
# 21                     test6  Undetected       None          Ok
# 22                JSQP241218  Undetected       None          Ok
# 23                JSQP241217  Undetected       None          Ok
# 24                              Complete       None          Ok
# 25                 barcode 1     Present       None          Ok
# 26                 barcode 2    Complete       None          Ok
# 27                  DLS_Stab     Present       None          Ok
# 28                 barcode 4    Complete       None          Ok
# 29                   C502981     Present       None          Ok
# 30                   C503586     Present       None          Ok
# 31                   C502984     Present       None          Ok
# 32                   C503124     Present       None          Ok
# 33                NN0001T2Q2     Present       None          Ok
# 34                NN0001T2TR     Present       None          Ok
# 35                 barcode 3     Present       None          Ok
# 36  AC-SINS_REF_SEP2024_mgmL     Present       None          Ok
# 37                              Complete       None          Ok
#
#      ContainerType                        Location  Position  IsInventory  \
# 0             None   Carousel:Column2_Hotel:Nest 1         1         True
# 1             None   Carousel:Column3_Hotel:Nest 1         1         True
# 2             None   Carousel:Column3_Hotel:Nest 2         1         True
# 3             None   Carousel:Column1_Hotel:Nest 3         1         True
# 4   GREINER 781280   Carousel:Column2_Hotel:Nest 3         1         True
# 5             None   Carousel:Column3_Hotel:Nest 3         1         True
# 6             None   Carousel:Column1_Hotel:Nest 4         1         True
# 7   GREINER 781280   Carousel:Column2_Hotel:Nest 4         1         True
# 8             None   Carousel:Column3_Hotel:Nest 4         1         True
# 9             None   Carousel:Column1_Hotel:Nest 5         1         True
# 10  GREINER 781280   Carousel:Column2_Hotel:Nest 5         1         True
# 11            None   Carousel:Column3_Hotel:Nest 5         1         True
# 12            None   Carousel:Column1_Hotel:Nest 6         1         True
# 13  GREINER 781280   Carousel:Column2_Hotel:Nest 6         1         True
# 14            None   Carousel:Column3_Hotel:Nest 6         1         True
# 15            None   Carousel:Column1_Hotel:Nest 7         1         True
# 16            None   Carousel:Column1_Hotel:Nest 8         1         True
# 17            None  Carousel:Column1_Hotel:Nest 11         1         True
# 18            None  Carousel:Column1_Hotel:Nest 12         1         True
# 19            None  Carousel:Column1_Hotel:Nest 13         1         True
# 20            None  Carousel:Column4_Hotel:Nest 13         1         True
# 21            None  Carousel:Column1_Hotel:Nest 14         1         True
# 22            None  Carousel:Column4_Hotel:Nest 14         1         True
# 23            None  Carousel:Column4_Hotel:Nest 15         1         True
# 24            None              Hotel:Nests:Nest 2         1         True
# 25            None        Liconic_1:Stack 1:Nest 1         1         True
# 26            None        Liconic_1:Stack 1:Nest 2         1         True
# 27            None        Liconic_1:Stack 1:Nest 3         1         True
# 28            None        Liconic_1:Stack 1:Nest 4         1         True
# 29            None        Liconic_2:Stack 1:Nest 1         1         True
# 30            None        Liconic_2:Stack 1:Nest 9         1         True
# 31            None       Liconic_2:Stack 1:Nest 10         1         True
# 32            None       Liconic_2:Stack 1:Nest 11         1         True
# 33            None        Liconic_3:Stack 1:Nest 1         1         True
# 34            None        Liconic_3:Stack 1:Nest 2         1         True
# 35            None        Liconic_3:Stack 1:Nest 3         1         True
# 36            None        Liconic_3:Stack 1:Nest 5         1         True
# 37            None              MicroSpin:Bucket 2         1         True
#
#     IsProcess                                          Inventory Process  \
# 0       False  {'TemplateName': 'T_SaltTitration_Destination'...    None
# 1       False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '0...    None
# 2       False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '6...    None
# 3       False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 4       False  {'TemplateName': 'T_OrangeGTest', 'ItemId': 'a...    None
# 5       False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '8...    None
# 6       False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 7       False  {'TemplateName': 'T_OrangeGTest', 'ItemId': 'f...    None
# 8       False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '8...    None
# 9       False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 10      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '3...    None
# 11      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '0...    None
# 12      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 13      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': 'e...    None
# 14      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '7...    None
# 15      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 16      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 17      False  {'TemplateName': 'T_Displacement_Assay', 'Item...    None
# 18      False  {'TemplateName': 'T_Displacement_Assay', 'Item...    None
# 19      False  {'TemplateName': 'T_Displacement_Assay', 'Item...    None
# 20      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': 'd...    None
# 21      False  {'TemplateName': 'T_Displacement_Assay', 'Item...    None
# 22      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': 'e...    None
# 23      False  {'TemplateName': 'T_OrangeGTest', 'ItemId': '9...    None
# 24      False  {'TemplateName': 'T_CounterBalance1', 'ItemId'...    None
# 25      False  {'TemplateName': 'T_kD_source', 'ItemId': '096...    None
# 26      False  {'TemplateName': 'T_kD_Assay', 'ItemId': 'f14e...    None
# 27      False  {'TemplateName': 'T_DLS_Stability', 'ItemId': ...    None
# 28      False  {'TemplateName': 'T_greiner788876', 'ItemId': ...    None
# 29      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 30      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 31      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 32      False  {'TemplateName': 'T_AC_SINS_Destination', 'Ite...    None
# 33      False  {'TemplateName': 'T_AC_SINS_Source', 'ItemId':...    None
# 34      False  {'TemplateName': 'T_AC_SINS_Source', 'ItemId':...    None
# 35      False  {'TemplateName': 'T_kD_Intermediate', 'ItemId'...    None
# 36      False  {'TemplateName': 'T_AC_SINS_Source', 'ItemId':...    None
# 37      False  {'TemplateName': 'T_CounterBalance2', 'ItemId'...    None
#
#                                                   Lid
# 0                                                None
# 1                                                None
# 2                                                None
# 3   {'Name': 'T_AC_SINS_DestinationLid (Id: 1398)'...
# 4                                                None
# 5                                                None
# 6   {'Name': 'T_AC_SINS_DestinationLid (Id: 1400)'...
# 7                                                None
# 8                                                None
# 9   {'Name': 'T_AC_SINS_DestinationLid (Id: 1402)'...
# 10                                               None
# 11                                               None
# 12  {'Name': 'T_AC_SINS_DestinationLid (Id: 1404)'...
# 13                                               None
# 14                                               None
# 15  {'Name': 'T_AC_SINS_DestinationLid (Id: 1406)'...
# 16  {'Name': 'T_AC_SINS_DestinationLid (Id: 1408)'...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29  {'Name': 'T_AC_SINS_DestinationLid (Id: 2368)'...
# 30  {'Name': 'T_AC_SINS_DestinationLid (Id: 2374)'...
# 31  {'Name': 'T_AC_SINS_DestinationLid (Id: 2370)'...
# 32  {'Name': 'T_AC_SINS_DestinationLid (Id: 2372)'...
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None

# %%
pd.DataFrame(m.get_barcodes("T_AC_SINS_Destination"))
# Out:
#       Barcode                       Location
# 0  NN0001SYUB  Carousel:Column1_Hotel:Nest 3
# 1  NN0001SYUA  Carousel:Column1_Hotel:Nest 4
# 2  NN0001SYU9  Carousel:Column1_Hotel:Nest 5
# 3  NN0001SYU8  Carousel:Column1_Hotel:Nest 6
# 4  NN0001SYU7  Carousel:Column1_Hotel:Nest 7
# 5  NN0001SYU6  Carousel:Column1_Hotel:Nest 8
# 6     C502981       Liconic_2:Stack 1:Nest 1
# 7     C503586       Liconic_2:Stack 1:Nest 9
# 8     C502984      Liconic_2:Stack 1:Nest 10
# 9     C503124      Liconic_2:Stack 1:Nest 11

# %%
pd.DataFrame(m.get_barcodes("T_AC_SINS_Destination","Carousel"))
# Out:
#       Barcode                       Location
# 0  NN0001SYUB  Carousel:Column1_Hotel:Nest 3
# 1  NN0001SYUA  Carousel:Column1_Hotel:Nest 4
# 2  NN0001SYU9  Carousel:Column1_Hotel:Nest 5
# 3  NN0001SYU8  Carousel:Column1_Hotel:Nest 6
# 4  NN0001SYU7  Carousel:Column1_Hotel:Nest 7
# 5  NN0001SYU6  Carousel:Column1_Hotel:Nest 8

# %%
m.get_instrument_nests("Liconic_1")
# Out:
# {'Liconic_1': ['Transfer Nest', 'Shovel Nest'],
#  'Stack 1': ['Nest 1',
#   'Nest 2',
#   'Nest 3',
#   'Nest 4',
#   'Nest 5',
#   'Nest 6',
#   'Nest 7',
#   'Nest 8',
#   'Nest 9',
#   'Nest 10',
#   'Nest 11',
#   'Nest 12',
#   'Nest 13',
#   'Nest 14',
#   'Nest 15',
#   'Nest 16',
#   'Nest 17',
#   'Nest 18',
#   'Nest 19',
#   'Nest 20',
#   'Nest 21',
#   'Nest 22'],
#  'Stack 2': ['Nest 1',
#   'Nest 2',
#   'Nest 3',
#   'Nest 4',
#   'Nest 5',
#   'Nest 6',
#   'Nest 7']}

# %%
df = pd.DataFrame(m.get_nests())
df
# Out:
#                               Name  IsAccessible  IsVirtual  IsSink  IsStack  \
# 0                         a4S:Nest          True      False   False    False
# 1                  Bioshake_1:Nest          True      False   False    False
# 2                  Bioshake_2:Nest          True      False   False    False
# 3          Carousel:Column5_Stack1          True      False   False     True
# 4    Carousel:Column1_Hotel:Nest 1          True      False   False    False
# ..                             ...           ...        ...     ...      ...
# 240           Tecan_Fluent:Nest 20         False      False   False    False
# 241             Tecan_Fluent:Waste          True      False    True    False
# 242             Tecan_Spark:Nest 1          True      False   False    False
# 243                     Waste:Nest          True      False    True    False
# 244                     XPeel:Nest          True      False   False    False
#
#                                  DeviceId    DeviceName Content StackContents
# 0    4f51db55-ca7c-4727-81c1-f6f802364f7c           a4S    None            []
# 1    3a7fddd5-cdc7-4978-a6d4-03e9819a565e    Bioshake_1    None            []
# 2    51806669-d2ac-410a-8cae-f55dec5e03b1    Bioshake_2    None            []
# 3    1335f9d0-6337-42fc-bc3a-d45ad209c15c      Carousel    None            []
# 4    1335f9d0-6337-42fc-bc3a-d45ad209c15c      Carousel    None            []
# ..                                    ...           ...     ...           ...
# 240  f47443eb-024d-477b-8cd4-708c8b02c957  Tecan_Fluent    None            []
# 241  f47443eb-024d-477b-8cd4-708c8b02c957  Tecan_Fluent    None            []
# 242  579119fc-de14-4743-b968-01abc7d1634c   Tecan_Spark    None            []
# 243  c5a69267-4d61-41c1-a357-0f954f2d5605         Waste    None            []
# 244  815d9399-7927-4c54-9fdb-fb811fe32c8b         XPeel    None            []
#
# [245 rows x 9 columns]

# %%
df[df['DeviceName']=="MicroSpin"]
# Out:
#                    Name  IsAccessible  IsVirtual  IsSink  IsStack  \
# 187  MicroSpin:Bucket 1          True      False   False    False
# 188  MicroSpin:Bucket 2          True      False   False    False
#
#                                  DeviceId DeviceName  \
# 187  084a8047-733e-44bd-a110-ca04bfd6d77a  MicroSpin
# 188  084a8047-733e-44bd-a110-ca04bfd6d77a  MicroSpin
#
#                                                Content StackContents
# 187                                               None            []
# 188  {'ContainerName': 'T_CounterBalance2 (Id: 1409...            []

# %%
containers = m.get_containers()
containers[0]
# Out:
# {'Id': '44168865-b358-4ab2-91c8-0ff0dbfb65da',
#  'Name': 'T_SaltTitration_Destination (Id: 2380, Barcode: salt1)',
#  'Barcode': 'salt1',
#  'State': 'Undetected',
#  'AbortState': 'None',
#  'FinishState': 'Ok',
#  'ContainerType': None,
#  'Location': 'Carousel:Column2_Hotel:Nest 1',
#  'Position': 1,
#  'IsInventory': True,
#  'IsProcess': False,
#  'Inventory': {'TemplateName': 'T_SaltTitration_Destination',
#   'ItemId': 'fd07ced2-4461-4be3-bf40-6d5c0e55d12b',
#   'SequenceId': 2380},
#  'Process': None,
#  'Lid': None}

# %%
ItemId = containers[0]["Inventory"]['ItemId']
ItemId
# Out:
# 'fd07ced2-4461-4be3-bf40-6d5c0e55d12b'

# %%
attributes = m.get_item_attribute(ItemId)
attributes
# Out:
# [{'Id': 'cbb50c00-4720-43db-a0d2-559c400e17a1',
#   'Name': 'Category',
#   'Flags': 'NonRemovable',
#   'Value': 'Plate',
#   'DataType': 'System.String',
#   'Created': '2024-12-13T11:29:34.207',
#   'Updated': None},
#  {'Id': '1a427154-25c9-4a75-a771-ff764828b44d',
#   'Name': 'SortIndex',
#   'Flags': 'ReadOnly, NonRemovable',
#   'Value': None,
#   'DataType': 'System.Int32',
#   'Created': '2024-12-13T11:29:34.207',
#   'Updated': None},
#  {'Id': '1c7a520c-b587-4421-a8a2-031179b5c95d',
#   'Name': 'LabwareType',
#   'Flags': 'PrivateAttribute, ReadOnlyGuest',
#   'Value': 'Greiner 655892',
#   'DataType': 'System.String',
#   'Created': '2024-12-13T11:29:34.207',
#   'Updated': None},
#  {'Id': '0caf22a6-c803-458e-ab38-032776c608fb',
#   'Name': 'Device',
#   'Flags': 'ReadOnly, NonRemovable, DoNotSave',
#   'Value': 'Carousel',
#   'DataType': 'System.String',
#   'Created': '2025-01-17T08:37:49.6389907Z',
#   'Updated': None},
#  {'Id': '24855fb3-e9a2-4b14-b167-a68bf5178c41',
#   'Name': 'IsUsed',
#   'Flags': 'ShowInGrids, PrivateAttribute, ReadOnlyGuest',
#   'Value': 'No',
#   'DataType': 'System.Boolean',
#   'Created': '2024-12-13T11:29:34.207',
#   'Updated': None},
#  {'Id': '7fe978bd-bcb8-4e82-a731-10eb9176e59d',
#   'Name': 'Owner',
#   'Flags': 'ReadOnly, NonRemovable, DoNotSave',
#   'Value': None,
#   'DataType': 'System.String',
#   'Created': '2025-01-17T08:37:49.6389907Z',
#   'Updated': None},
#  {'Id': '97c51f90-92ed-4679-96b8-fe8899de953b',
#   'Name': 'SequenceId',
#   'Flags': 'ReadOnly, NonRemovable',
#   'Value': '2380',
#   'DataType': 'System.Int32',
#   'Created': '2024-12-13T11:29:34.207',
#   'Updated': None},
#  {'Id': '4440287c-c3fb-41ac-b090-cff27608845a',
#   'Name': 'ReadOnFirstGet',
#   'Flags': 'NonRemovable',
#   'Value': 'false',
#   'DataType': 'System.Boolean',
#   'Created': '2024-12-13T11:29:34.21',
#   'Updated': None},
#  {'Id': 'c88ca45e-fc79-494b-9c0a-462501c94a82',
#   'Name': 'Lidded',
#   'Flags': 'ReadOnly, NonRemovable, ShowInGrids',
#   'Value': 'false',
#   'DataType': 'System.Boolean',
#   'Created': '2024-12-13T11:29:34.21',
#   'Updated': None},
#  {'Id': '2f1d95be-5c58-47d1-9f39-7199b7ddcb7e',
#   'Name': 'Barcode',
#   'Flags': 'NonRemovable, ShowInGrids, ReadOnlyDefault',
#   'Value': 'salt1',
#   'DataType': 'System.String',
#   'Created': '2024-12-13T11:29:34.21',
#   'Updated': None},
#  {'Id': '7b27f546-ca3b-4ef2-8c11-ea18d7a3124b',
#   'Name': 'Experiment',
#   'Flags': 'ShowInGrids, PrivateAttribute, ReadOnlyGuest',
#   'Value': None,
#   'DataType': 'System.String',
#   'Created': '2024-12-13T11:29:34.21',
#   'Updated': None},
#  {'Id': '2bba1428-0487-484c-a97f-49a1c468a505',
#   'Name': 'HasLid',
#   'Flags': 'ReadOnly, NonRemovable',
#   'Value': 'false',
#   'DataType': 'System.Boolean',
#   'Created': '2024-12-13T11:29:34.21',
#   'Updated': None},
#  {'Id': 'e38526f9-a988-44d2-bc45-bb2d61625906',
#   'Name': 'EchoPlateID',
#   'Flags': 'ShowInGrids, PrivateAttribute, ReadOnlyGuest',
#   'Value': '-1',
#   'DataType': 'System.Int32',
#   'Created': '2024-12-13T11:29:34.21',
#   'Updated': None},
#  {'Id': 'df6b5d1b-7fb1-4400-be9e-4791cf3a0d3f',
#   'Name': 'Role',
#   'Flags': 'ReadOnly, NonRemovable, DoNotSave',
#   'Value': 'T_SaltTitration_Destination',
#   'DataType': 'System.String',
#   'Created': '2025-01-17T08:37:49.6389907Z',
#   'Updated': '2025-01-17T09:37:49.8579282+01:00'}]

# %%
attributes
# Out:
# <coroutine object Momentum.get_container_attributes at 0x0000026C08B14510>
