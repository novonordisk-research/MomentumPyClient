# %%
from MomentumPyClient import Momentum
import pandas as pd
import time

m = Momentum()
m.get_status()
# Out:
# {'State': 'Offline', 'Attended': True, 'Simulated': True}

# %%
m.get_version()
# Out:
# {'Version': '7.3.0'}

# %%
m.stop()
m.get_status()
# Out:
# {'State': 'Offline', 'Attended': True, 'Simulated': True}

# %%
m.simulate()
time.sleep(4)
m.get_status()
# Out:
# {'State': 'Online', 'Attended': True, 'Simulated': True}

# %%
m.get_instrument_names()
# Out:
# ['a4S',
#  'Bioshake_1',
#  'Bioshake_2',
#  'Carousel',
#  'DynaPro',
#  'Echo',
#  'Hotel',
#  'Liconic_1',
#  'Liconic_2',
#  'Liconic_3',
#  'Lidpark',
#  'Mantis',
#  'MicroSpin',
#  'PassiveNest_1',
#  'PassiveNest_2',
#  'RotationStation',
#  'SpinnakerBT_1',
#  'SpinnakerBT_2',
#  'Stunner',
#  'SwapStation',
#  'Tecan_Fluent',
#  'Tecan_Spark',
#  'Waste',
#  'XPeel']

# %%
m.get_process_names()

# %%
m.run_process("Process1")
# Out:
# {'WorkUnitsSubmitted': [{'Id': '6fef8bab-1c94-45ea-bad9-372a28052836',
#    'Name': 'Work Unit 1960'}]}

# %%
pd.DataFrame(m.get_devices())
# Out:
#                                       Id                 Name        Mode  \
# 0   4f51db55-ca7c-4727-81c1-f6f802364f7c                  a4S      Normal
# 1   214e834c-f610-40cc-80ce-eb7942cddf06  ApplicationLauncher      Normal
# 2   6043bfa4-3328-4cbc-a600-05afc956b7cc               Beacon      Normal
# 3   3a7fddd5-cdc7-4978-a6d4-03e9819a565e           Bioshake_1      Normal
# 4   51806669-d2ac-410a-8cae-f55dec5e03b1           Bioshake_2      Normal
# 5   1335f9d0-6337-42fc-bc3a-d45ad209c15c             Carousel      Normal
# 6   d6659913-6630-4f50-8b9d-815da7740772     ContainerScanner      Normal
# 7   eeba0e63-1fa1-4b4c-9db1-f22020d468a9              Docking      Normal
# 8   5dd5ab0d-1990-4061-9e20-2eaef1805c39              DynaPro      Normal
# 9   4037e7bd-b249-425a-92ce-ae24dfa14109                 Echo      Normal
# 10  afb5b5c3-c91e-49e3-8430-1de6f824e0f6          FileManager      Normal
# 11  a0387028-39c6-49f8-9f94-9e359b7aa6de                Hotel      Normal
# 12  593a806e-38bf-4c37-9830-b8e5cd5f0e52            Liconic_1      Normal
# 13  b0a8db49-ee8c-4383-a878-cdcc5df4e8cb            Liconic_2      Normal
# 14  9110a8a1-6564-447c-b639-07da8cabefbb            Liconic_3      Normal
# 15  b1e7f0fd-0cdb-4f83-af68-0b1730f95c05              Lidpark      Normal
# 16  778eed5c-429f-40ac-9f5f-2d478dbb27c0               Mantis      Normal
# 17  084a8047-733e-44bd-a110-ca04bfd6d77a            MicroSpin      Normal
# 18  9c67eb09-1be9-4534-91b8-e83f57237e2e     MomentumOperator      Normal
# 19  ed1d474e-245c-46a7-8054-ab48a6b9379c        PassiveNest_1      Normal
# 20  1910398c-f5f7-4a4b-aa5e-2a8dcde99c79        PassiveNest_2      Normal
# 21  5969fdbb-72d4-41de-a7ea-ab8a036be7d3      RotationStation      Normal
# 22  2dc029f7-4437-40e6-8e82-8536ef567a54        SpinnakerBT_1      Normal
# 23  dd83075e-9cb5-4347-8308-43b79ba1cacc        SpinnakerBT_2      Normal
# 24  489733e8-11d1-4b91-b731-cfa5a4e45947          SwapStation      Normal
# 25  f47443eb-024d-477b-8cd4-708c8b02c957         Tecan_Fluent  Simulation
# 26  579119fc-de14-4743-b968-01abc7d1634c          Tecan_Spark      Normal
# 27  c5a69267-4d61-41c1-a357-0f954f2d5605                Waste      Normal
# 28  5e30c241-4c66-41b0-9c5e-4722b015fa37          Wtio_Beacon      Normal
# 29  938c77b6-f4a5-4313-a5bf-4a9c76863963         Wtio_Lidpark      Normal
# 30  3701c66e-dfe3-49a0-a977-1bd3de521907          Wtio_Regrip      Normal
# 31  815d9399-7927-4c54-9fdb-fb811fe32c8b                XPeel      Normal
#
#      State OnlineState  Active  Available DockState  Present  IsSimulated  \
# 0   Online        Idle   False       True    Docked     True         True
# 1   Online        Idle   False       True    Docked     True         True
# 2   Online        Idle   False       True    Docked     True         True
# 3   Online        Idle   False       True    Docked     True         True
# 4   Online        Idle   False       True    Docked     True         True
# 5   Online        Idle   False       True    Docked     True         True
# 6   Online        Idle   False       True    Docked     True         True
# 7   Online        Idle   False       True    Docked     True         True
# 8   Online        Idle   False       True    Docked     True         True
# 9   Online        Idle   False       True    Docked     True         True
# 10  Online        Idle   False       True    Docked     True         True
# 11  Online        Idle   False       True    Docked     True         True
# 12  Online        Idle   False       True    Docked     True         True
# 13  Online        Idle   False       True    Docked     True         True
# 14  Online        Idle   False       True    Docked     True         True
# 15  Online        Idle   False       True    Docked     True         True
# 16  Online        Idle   False       True    Docked     True         True
# 17  Online        Idle   False       True    Docked     True         True
# 18  Online        Idle   False       True    Docked     True         True
# 19  Online        Idle   False       True    Docked     True         True
# 20  Online        Idle   False       True    Docked     True         True
# 21  Online        Idle   False       True    Docked     True         True
# 22  Online        Idle   False       True    Docked     True         True
# 23  Online        Idle   False       True    Docked     True         True
# 24  Online        Idle   False       True    Docked     True         True
# 25  Online        Idle   False       True    Docked     True         True
# 26  Online        Idle   False       True    Docked     True         True
# 27  Online        Idle   False       True    Docked     True         True
# 28  Online        Idle   False       True    Docked     True         True
# 29  Online        Idle   False       True    Docked     True         True
# 30  Online        Idle   False       True    Docked     True         True
# 31  Online        Idle   False       True    Docked     True         True
#
#     IsInstrument  Priority FirmwareVersion  \
# 0           True         2            515A
# 1          False         2  Not available.
# 2          False         2  Not available.
# 3           True         2          1.8.00
# 4           True         2          1.8.00
# 5           True         2  Not available.
# 6          False         2             N/A
# 7          False         0  Not available.
# 8           True         2  Not available.
# 9           True         2  Not available.
# 10         False         2  Not available.
# 11          True         2  Not available.
# 12          True         2  Not available.
# 13          True         2  Not available.
# 14          True         2  Not available.
# 15          True         2  Not available.
# 16          True         2  Not available.
# 17          True         2  Not available.
# 18         False         2  Not available.
# 19          True         2  Not available.
# 20          True         2  Not available.
# 21          True         2  Not available.
# 22          True         1  Not available.
# 23          True         1  Not available.
# 24          True         2  Not available.
# 25          True         2  Not available.
# 26          True         2  Not available.
# 27          True         2  Not available.
# 28         False         0  Not available.
# 29         False         0  Not available.
# 30         False         0  Not available.
# 31          True         2            2.11
#
#                              SoftwareVersion  \
# 0                 Communication Protocol 1.7
# 1                             Not available.
# 2                             Not available.
# 3                             Not available.
# 4                             Not available.
# 5                             Not available.
# 6                                    3.0.0.0
# 7                             Not available.
# 8                             Not available.
# 9                                      3.2.2
# 10                            Not available.
# 11                            Not available.
# 12                                       N/A
# 13                                       N/A
# 14                                       N/A
# 15                            Not available.
# 16                            Not available.
# 17                            Not available.
# 18                            Not available.
# 19                            Not available.
# 20                            Not available.
# 21                            Not available.
# 22  Thermo Scientific Mover Framework 2.4.30
# 23  Thermo Scientific Mover Framework 2.4.30
# 24                            Not available.
# 25                            Not available.
# 26                            Not available.
# 27                            Not available.
# 28                            Not available.
# 29                            Not available.
# 30                            Not available.
# 31                                       N/A
#
#                               ModelDescription    SerialNumber ConnectionMode  \
# 0                               Not available.  Not available.        Unknown
# 1                               Not available.  Not available.        Unknown
# 2                               Not available.  Not available.        Unknown
# 3                      Q.MTP-BIOSHAKE 5000 elm  Not available.        Unknown
# 4                      Q.MTP-BIOSHAKE 5000 elm  Not available.        Unknown
# 5                               Not available.  Not available.        Unknown
# 6             Thermo.Momentum.ContainerScanner             N/A        Unknown
# 7                               Not available.  Not available.        Unknown
# 8                               Not available.  Not available.        Unknown
# 9                                     Echo 650      E6XX-22158        Unknown
# 10                              Not available.  Not available.        Unknown
# 11                              Not available.  Not available.        Unknown
# 12                                      STX110  Not available.        Unknown
# 13                                      STX110  Not available.        Unknown
# 14                                      STX110  Not available.        Unknown
# 15                              Not available.  Not available.        Unknown
# 16                              Not available.  Not available.        Unknown
# 17                              Not available.  Not available.        Unknown
# 18                              Not available.  Not available.        Unknown
# 19                              Not available.  Not available.        Unknown
# 20                              Not available.  Not available.        Unknown
# 21                              Not available.  Not available.        Unknown
# 22  Thermo Scientific Spinnaker with BenchTrak  Not available.        Unknown
# 23  Thermo Scientific Spinnaker with BenchTrak  Not available.        Unknown
# 24                              Not available.  Not available.        Unknown
# 25                              Not available.  Not available.        Unknown
# 26                              Not available.  Not available.        Unknown
# 27                              Not available.  Not available.        Unknown
# 28                              Not available.  Not available.        Unknown
# 29                              Not available.  Not available.        Unknown
# 30                              Not available.  Not available.        Unknown
# 31                      Nexus Biosystems XPeel                        Unknown
#
#                                                 Type  IsWasteInstrument
# 0             4titude Automatic Roll Heat Sealer a4S              False
# 1             Thermo Scientific Application Launcher              False
# 2                           Thermo Scientific Beacon              False
# 3         QInstruments BioShake 5000 Series - Single              False
# 4         QInstruments BioShake 5000 Series - Single              False
# 5   Thermo Scientific Thermotor Carousel - 8 Columns              False
# 6                Thermo Scientific Container Scanner              False
# 7           Thermo Scientific Docking Inputs Monitor              False
# 8                                      Wyatt DynaPro              False
# 9                 Labcyte Echo6XX Acoustic Dispenser              False
# 10                    Thermo Scientific File Manager              False
# 11               Thermo Scientific General Incubator              False
# 12               Liconic StoreX STX Series Incubator              False
# 13               Liconic StoreX STX Series Incubator              False
# 14               Liconic StoreX STX Series Incubator              False
# 15       Thermo Scientific Lid Park Station Delidder              False
# 16                                Formulatrix Mantis              False
# 17                      HighRes MicroSpin Centrifuge              False
# 18             Thermo Scientific Momentum Operator 4              False
# 19               Thermo Scientific General Incubator              False
# 20               Thermo Scientific General Incubator              False
# 21                Thermo Scientific Rotation Station              False
# 22                           Thermo Scientific Mover              False
# 23                           Thermo Scientific Mover              False
# 24                    Thermo Scientific Swap Station              False
# 25                                      Tecan Fluent              False
# 26                             Tecan Spark(Magellan)              False
# 27                   Thermo Scientific General Waste               True
# 28          White Tree Technology WTIO-1 Input/Ouput              False
# 29          White Tree Technology WTIO-1 Input/Ouput              False
# 30          White Tree Technology WTIO-1 Input/Ouput              False
# 31                            Nexus Biosystems XPeel              False

# %%
pd.DataFrame(m.get_containers())

# %%
pd.DataFrame(m.get_barcodes("T_Plate1"))

# %%
pd.DataFrame(m.get_barcodes("T_Plate1","Carousel"))

# %%
m.get_instrument_nests("Carousel")
# Out:
# {'Column1_Hotel': ['Nest 1',
#   'Nest 2',
#   'Nest 3',
#   'Nest 4',
#   'Nest 5',
#   'Nest 6',
#   'Nest 7',
#   'Nest 8',
#   'Nest 9',
#   'Nest 10',
#   'Nest 11',
#   'Nest 12',
#   'Nest 13',
#   'Nest 14',
#   'Nest 15'],
#  'Column2_Hotel': ['Nest 1',
#   'Nest 2',
#   'Nest 3',
#   'Nest 4',
#   'Nest 5',
#   'Nest 6',
#   'Nest 7',
#   'Nest 8',
#   'Nest 9',
#   'Nest 10',
#   'Nest 11',
#   'Nest 12',
#   'Nest 13',
#   'Nest 14',
#   'Nest 15'],
#  'Column3_Hotel': ['Nest 1',
#   'Nest 2',
#   'Nest 3',
#   'Nest 4',
#   'Nest 5',
#   'Nest 6',
#   'Nest 7',
#   'Nest 8',
#   'Nest 9',
#   'Nest 10',
#   'Nest 11',
#   'Nest 12',
#   'Nest 13',
#   'Nest 14',
#   'Nest 15'],
#  'Column4_Hotel': ['Nest 1',
#   'Nest 2',
#   'Nest 3',
#   'Nest 4',
#   'Nest 5',
#   'Nest 6',
#   'Nest 7',
#   'Nest 8',
#   'Nest 9',
#   'Nest 10',
#   'Nest 11',
#   'Nest 12',
#   'Nest 13',
#   'Nest 14',
#   'Nest 15']}

# %%
df = pd.DataFrame(m.get_nests())
df
# Out:
#                               Name  IsAccessible  IsVirtual  IsSink  IsStack  \
# 0                         a4S:Nest          True      False   False    False
# 1                  Bioshake_1:Nest          True      False   False    False
# 2                  Bioshake_2:Nest          True      False   False    False
# 3          Carousel:Column5_Stack1          True      False   False     True
# 4    Carousel:Column1_Hotel:Nest 1          True      False   False    False
# ..                             ...           ...        ...     ...      ...
# 257           Tecan_Fluent:Nest 20          True      False   False    False
# 258             Tecan_Fluent:Waste          True      False    True    False
# 259             Tecan_Spark:Nest 1          True      False   False    False
# 260                     Waste:Nest          True      False    True    False
# 261                     XPeel:Nest          True      False   False    False
#
#                                  DeviceId    DeviceName  \
# 0    4f51db55-ca7c-4727-81c1-f6f802364f7c           a4S
# 1    3a7fddd5-cdc7-4978-a6d4-03e9819a565e    Bioshake_1
# 2    51806669-d2ac-410a-8cae-f55dec5e03b1    Bioshake_2
# 3    1335f9d0-6337-42fc-bc3a-d45ad209c15c      Carousel
# 4    1335f9d0-6337-42fc-bc3a-d45ad209c15c      Carousel
# ..                                    ...           ...
# 257  f47443eb-024d-477b-8cd4-708c8b02c957  Tecan_Fluent
# 258  f47443eb-024d-477b-8cd4-708c8b02c957  Tecan_Fluent
# 259  579119fc-de14-4743-b968-01abc7d1634c   Tecan_Spark
# 260  c5a69267-4d61-41c1-a357-0f954f2d5605         Waste
# 261  815d9399-7927-4c54-9fdb-fb811fe32c8b         XPeel
#
#                                                Content StackContents
# 0                                                 None            []
# 1                                                 None            []
# 2                                                 None            []
# 3                                                 None            []
# 4    {'ContainerName': '*T_Destination (Id: 840, Ba...            []
# ..                                                 ...           ...
# 257                                               None            []
# 258                                               None            []
# 259                                               None            []
# 260                                               None            []
# 261                                               None            []
#
# [262 rows x 9 columns]

# %%
df[df['DeviceName']=="MicroSpin"]

# %%
containers = m.get_containers()
containers[0]

# %%
ItemId = containers[0]["Inventory"]['ItemId']
ItemId

# %%
attributes = m.get_item_attribute(ItemId)
attributes

# %%
attributes

# %%
items = [
                {
                    "Template": "T_Destination",
                    "Nest": "Carousel:Column2_Hotel:Nest 1",
                    "HasLid": False,
                    "Barcode" : "ABC123"
                }
           ]

m.add_inventyory_items(items)
